# %% [markdown]
# <a href="https://colab.research.google.com/github/MakhamudDrame/ML_lab/blob/main/LAB_1_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Машинное обучение, МАИ & СБЕР

# %% [markdown]
# ## Лабораторная работа № 1

# %% [markdown]
# ## О задании
#
# Задание состоит из последовательных вопросов, посвященных работе с табличными данными с помощью библиотеки Pandas и визуализации с помощью библиотеки Seaborn.
#
# Баллы даются за выполнение отдельных пунктов (Максимальное количество баллов за эту Л.Р. - 5)
#
# Задачи в рамках одного раздела рекомендуется решать в том порядке, в котором они даны в задании.
#
# Задание направлено на освоение Jupyter notebook (будет использоваться в дальнейших заданиях), библиотек Pandas и Seaborn.
#
# ***DeadLine: 02.03.2025 23:59***

# %% [markdown]
# ## Инструкция по сдаче ДЗ.

# %% [markdown]
# 0. Просмотр лекции обязателен. Не потому что без этого невозможно выполнить домашнее задание, а потому что с этим выполнение домашнего задания станет комфортным, приятным и быстрым. Вы потратите намного меньше времени для изучения материала и понимания того, что от Вас хотят, нежели сразу приступите к выполнению домашнего задания без просмотра лекции.

# %% [markdown]
# 1. Скопируйте к себе колаб-ноутбук.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 2. у Вас откроется файл в новой вкладке с названием "Копия...". После описания задания вы пишите решение этого задания.
#
# ![Снимок экрана 2023-11-19 в 19.27.13.png](data:image/png;base64,...)![image.png](data:image/png;base64,...)

# %% [markdown]
# 3. После выполнения домашнего задания нажмите кнопку "поделиться" и перейдите в режим доступно всем по ссылке
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 4. Загрузите эту ссылку в lms.mai.ru по курсу "Машинное обучение" в качестве ссылки в раздел "Pandas - работа с таблицами для машинного обучения (ЛР) [17.02]"

# %% [markdown]
# # Задание

# %% [markdown]
# ## Скачивание датасета и чтение данных

# %% [markdown]
# **Описание данных:**
#
# Boston Housing Dataset - это набор данных, полученный из информации, собранной Управлением переписи населения США о жилье в районе Бостона, штат Массачусетс. Ниже приведено описание столбцов датасета:
#
# CRIM - уровень преступности на душу населения по городам
#
# ZN - доля жилой земли, зонированной под участки более 25,000 кв.фт.
#
# INDUS - доля акров нерозничной торговли по городам.
#
# CHAS - переменная-индикатор реки Чарльз (1, если участок граничит с рекой; 0 в противном случае)
#
# NOX - концентрация оксидов азота (частиц на 10 миллионов)
#
# RM - среднее количество комнат в жилом помещении
#
# AGE - доля занимаемых владельцами жилых единиц, построенных до 1940 года
#
# DIS - взвешенное расстояние до пяти центров занятости Бостона
#
# RAD - индекс доступности радиальных магистралей
#
# TAX - ставка налога на недвижимость полной стоимости за $10,000
#
# PTRATIO - соотношение учеников и учителей по городам
#
# B - 1000(Bk - 0.63)^2, где Bk - доля чернокожего населения по городам
#
# LSTAT - % населения с низким социальным статусом
#
# MEDV - медианная стоимость домов, занимаемых владельцами, в тысячах долларов
#
# **Оригинал: (для удобства выше предоставил перевод описания данных на русский язык)**
#
# The Boston Housing Dataset
#
# The Boston Housing Dataset is a derived from information collected by the U.S. Census Service concerning housing in the area of Boston MA. The following describes the dataset columns:
#
# CRIM - per capita crime rate by town
#
# ZN - proportion of residential land zoned for lots over 25,000 sq.ft.
#
# INDUS - proportion of non-retail business acres per town.
#
# CHAS - Charles River dummy variable (1 if tract bounds river; 0 otherwise)
#
# NOX - nitric oxides concentration (parts per 10 million)
#
# RM - average number of rooms per dwelling
#
# AGE - proportion of owner-occupied units built prior to 1940
#
# DIS - weighted distances to five Boston employment centres
#
# RAD - index of accessibility to radial highways
#
# TAX - full-value property-tax rate per $10,000
#
# PTRATIO - pupil-teacher ratio by town
#
# B - 1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
#
# LSTAT - % lower status of the population
#
# MEDV - Median value of owner-occupied homes in $1000's
#
# Источник данных: https://www.kaggle.com/datasets/vikrishnan/boston-house-prices

# %%
#################################------------------------------------------------------#################################

# %% [markdown]
# **Да, невсегда просто взять и считать данные.**
#
# **Wget** - утилита, которая помогает получить файл, -o (output) указывает название файла, по которому мы хотим сохранить файл
#
# **Восклицательный знак** обозначает, что мы обращаемся к UNIX системе и хотим выполнить некоторые терминальные команды
#
# ***Как*** отработать эти команды? Я вижу несколько вариантов:
#
# -> ***Попробовать*** месяц не использовать UI интерфейс, а пользоваться терминалов вашей OC
#
# -> ***Гуглить*** по мере необходимости, Learning by practice, как завещал Илон Маск)
#
# -> А еще есть ***забавный курс по UNIX***, который дает понимание основных терминальных команд, вот [ссылочка](https://stepik.org/course/7353/promo):

# %%
import pandas as pd

# !wget 'https://drive.google.com/uc?export=download&id=1bLimsjkc4--W7wI6FVzPQ2K_lu6D5_CX' -O housing.csv
column_names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'TARGET']
df = pd.read_csv('housing.csv', header=None, delimiter=r"\s+", names=column_names)
df
# Out:
# --2025-03-02 16:38:48--  https://drive.google.com/uc?export=download&id=1bLimsjkc4--W7wI6FVzPQ2K_lu6D5_CX
# Resolving drive.google.com (drive.google.com)... 142.250.65.110, 2607:f8b0:4025:804::200e
# Connecting to drive.google.com (drive.google.com)|142.250.65.110|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://drive.usercontent.google.com/download?id=1bLimsjkc4--W7wI6FVzPQ2K_lu6D5_CX&export=download [following]
# --2025-03-02 16:38:48--  https://drive.usercontent.google.com/download?id=1bLimsjkc4--W7wI6FVzPQ2K_lu6D5_CX&export=download
# Resolving drive.usercontent.google.com (drive.usercontent.google.com)... 172.217.164.1, 2607:f8b0:4025:803::2001
# Connecting to drive.usercontent.google.com (drive.usercontent.google.com)|172.217.164.1|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 49082 (48K) [application/octet-stream]
# Saving to: ‘housing.csv’
#
# housing.csv         100%[===================>]  47.93K  --.-KB/s    in 0s
#
# 2025-03-02 16:38:50 (120 MB/s) - ‘housing.csv’ saved [49082/49082]
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273.0
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273.0
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273.0
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273.0
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273.0
#
#      PTRATIO       B  LSTAT  TARGET
# 0       15.3  396.90   4.98    24.0
# 1       17.8  396.90   9.14    21.6
# 2       17.8  392.83   4.03    34.7
# 3       18.7  394.63   2.94    33.4
# 4       18.7  396.90   5.33    36.2
# ..       ...     ...    ...     ...
# 501     21.0  391.99   9.67    22.4
# 502     21.0  396.90   9.08    20.6
# 503     21.0  396.90   5.64    23.9
# 504     21.0  393.45   6.48    22.0
# 505     21.0  396.90   7.88    11.9
#
# [506 rows x 14 columns]

# %% [markdown]
# 1. **Обработка пропущенных значений**: [+1 балл]
#    - Вычислить процент пропущенных значений для каждой колонки.
#    - Решение о заполнении пропущенных значений:
#      - Если пропуски незначительны, рассмотреть их удаление.
#      - Если пропуски значительны, рассмотреть заполнение средним/медианой/модой или использование методов импутации.

# %%
df.isnull().mean()
# Out:
# CRIM       0.0
# ZN         0.0
# INDUS      0.0
# CHAS       0.0
# NOX        0.0
# RM         0.0
# AGE        0.0
# DIS        0.0
# RAD        0.0
# TAX        0.0
# PTRATIO    0.0
# B          0.0
# LSTAT      0.0
# TARGET     0.0
# dtype: float64

# %% [markdown]
# Пропуски отсутствуют

# %% [markdown]
# 2. **Приведение типов данных**: [+0.25 балла]
#    - Для каждой колонки проверить соответствие типа данных её содержимому (например, числовой тип для `TAX`, категориальный для `CHAS`).
#    - При необходимости, изменить тип данных колонок.

# %%
df.dtypes
# Out:
# CRIM       float64
# ZN         float64
# INDUS      float64
# CHAS         int64
# NOX        float64
# RM         float64
# AGE        float64
# DIS        float64
# RAD          int64
# TAX        float64
# PTRATIO    float64
# B          float64
# LSTAT      float64
# TARGET     float64
# dtype: object

# %%
df.RAD.unique()
# Out:
# array([ 1,  2,  3,  5,  4,  8,  6,  7, 24])

# %% [markdown]
# Почти все переменные имеют тип float, кроме CHAS и RAD. Charles River dummy variable это категориальная переменная, где 1 признак есть и 0 признака нет, поэтому ее тип изменять не требуется(one hot encoding). RAD - индекс доступности магистралей, он целочисленный, чем выше - тем лучше, его тип тоже оставим как есть

# %% [markdown]
# 3. **Проверка распределений переменных**: [+0.25 балла]
#    - Построение гистограмм: для каждой числовой переменной c помощью библиотеки Seaborn.
#    - Построение ящиков с усами (boxplot): идентификация потенциальных выбросов с помощью библиотеки Seaborn.

# %%
import seaborn as sns
import matplotlib.pyplot as plt

n_cols = 5
n_rows = 3

fig, axes = plt.subplots(nrows=n_rows, ncols=n_cols, figsize=(20, n_rows * 4))
axes = axes.flatten()

for i, column in enumerate(df.columns):
    sns.histplot(df[column], ax=axes[i], color='orange')

for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %%
exclude_column = 'CHAS'
to_plot = [col for col in df.columns if col != exclude_column]

n_cols = 5
n_rows = 3

fig, axes = plt.subplots(nrows=n_rows, ncols=n_cols, figsize=(20, n_rows * 4))
axes = axes.flatten()

for i, column in enumerate(to_plot):
    sns.boxplot(y=df[column], ax=axes[i], color='lightgreen')

for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %% [markdown]
# 4. **Обработка выбросов**: [+1 балл]
#    - Определить пороги для выбросов на основе статистических мер (например, IQR)
#    - Решить, удалять ли выбросы или корректировать их значения.

# %%
filtered_df = df.copy()

for col in df.columns:
  Q1 = df[col].quantile(0.25)
  Q3 = df[col].quantile(0.75)
  IQR = Q3 - Q1
  mid=df[col].quantile(0.5)
  lower_bound = Q1 - 1.5 * IQR
  upper_bound = Q3 + 1.5 * IQR

  print(f'{col}  {lower_bound}  {mid}  {upper_bound}')

  filtered_df = filtered_df[(filtered_df[col] >= lower_bound) & (filtered_df[col] <= upper_bound)]
# Out:
# CRIM  -5.31051125  0.25651  9.06963875
# ZN  -18.75  0.0  31.25
# INDUS  -14.175  9.69  37.465
# CHAS  0.0  0.0  0.0
# NOX  0.18650000000000005  0.538  0.8865
# RM  4.778499999999999  6.2085  7.730500000000001
# AGE  -28.54999999999999  77.5  167.64999999999998
# DIS  -2.5322000000000005  3.2074499999999997  9.820800000000002
# RAD  -26.0  5.0  54.0
# TAX  -301.5  330.0  1246.5
# PTRATIO  13.199999999999998  19.05  24.4
# B  344.10624999999993  391.44  427.49625000000003
# LSTAT  -8.057500000000005  11.36  31.962500000000006
# TARGET  5.0624999999999964  21.2  36.962500000000006

# %%
print(filtered_df.shape[0]/df.shape[0])
# Out:
# 0.5296442687747036

# %% [markdown]
# Мы имееюм всего 506 наблюдений в датасете, лучше отказаться от удаления выбросов. Отфильтрованный по lower_bound и upper_bound датасет ненамного больше выбросов, которые туда не попали.  Удаление или корректировка таких выбросов может исказить реальную картину и привести к потере важной информации.

# %% [markdown]
# ### Что такое IQR и как его использовать для обработки выбросов:
#
# **IQR (Interquartile Range)**, или межквартильный размах, это мера статистического разброса и используется для определения выбросов. IQR рассчитывается как разность между 75-м и 25-м процентилями данных (Q3 и Q1 соответственно).
#
# Выбросы часто определяются как значения, которые находятся за пределами следующих границ:
# - Нижняя граница: Q1 - 1.5 * IQR
# - Верхняя граница: Q3 + 1.5 * IQR
#
# #### Примерный код на Python с использованием pandas:
#
# ```python
# import pandas as pd
#
# # Загрузка данных
# df = pd.read_csv('path_to_file.csv')
#
# # Рассчитываем IQR для колонки 'example_column'
# Q1 = df['example_column'].quantile(0.25)
# Q3 = df['example_column'].quantile(0.75)
# IQR = Q3 - Q1
#
# # Определяем границы для выбросов
# lower_bound = Q1 - 1.5 * IQR
# upper_bound = Q3 + 1.5 * IQR
#
# # Фильтрация данных для удаления или корректировки выбросов
# filtered_df = df[(df['example_column'] >= lower_bound) & (df['example_column'] <= upper_bound)]
# ```

# %% [markdown]
# 5. **Статистические выводы**: [+0.5 балла]
#    - Вычисление основных статистических метрик для каждой переменной (среднее, медиана, минимум, максимум)
#    - Сделать письменные развернутые выводы в отдельной текстовой ячейке: сильно ли отличается среднее от медианы, как сильно друг от друга удалены минимум и максимум, рассчитать среднее отклонение и дисперсию

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# std     28.148861    2.105710    8.707259  168.537116    2.164946   91.294864
# min      2.900000    1.129600    1.000000  187.000000   12.600000    0.320000
# 25%     45.025000    2.100175    4.000000  279.000000   17.400000  375.377500
# 50%     77.500000    3.207450    5.000000  330.000000   19.050000  391.440000
# 75%     94.075000    5.188425   24.000000  666.000000   20.200000  396.225000
# max    100.000000   12.126500   24.000000  711.000000   22.000000  396.900000
#
#             LSTAT      TARGET
# count  506.000000  506.000000
# mean    12.653063   22.532806
# std      7.141062    9.197104
# min      1.730000    5.000000
# 25%      6.950000   17.025000
# 50%     11.360000   21.200000
# 75%     16.955000   25.000000
# max     37.970000   50.000000

# %% [markdown]
# 1. CRIM - уровень преступности на душу населения по городам. Он сильно варьируется. Медиана значительно ниже среднего значения, что указывает на наличие выбросов с высоким уровнем преступности, высокая дисперсия и стандартное отклонение это подтверждают.
#
# 2. ZN - доля жилой земли, зонированной под участки более 25,000 кв.фт. Большинство районов не имеют участков такого размера -медиана равна 0. Высокая дисперсия указывает на значительные различия между районами.
#
# 3. INDUS - доля акров нерозничной торговли по городам. Медиана близка к среднему значению. Минимальные и максимальные значения значительно отличаются от среднего,  это говорит о том, что в некоторых районах эта доля может быть либо очень низкой, либо очень высокой.
#
# 4. CHAS - переменная-индикатор реки Чарльз. Только около 5.9% районов находятся рядом с рекой Чарльз. Это бинарная переменная, что подтверждается медианой со значением 0.
#
# 5.  NOX - концентрация оксидов азота (частиц на 10 миллионов). Среднее и медиана близки по значению, разброс в данных минимальный.
#
# 6. RM - среднее количество комнат в жилом помещении. Среднее и медиана близки по значению, разброс в данных минимальный.
#
# 7. AGE - доля занимаемых владельцами жилых единиц, построенных до 1940 года. Медиана значительно выше среднего значения. Имеем  выбросы с низкими значениями, то есть в некоторых районах доля старых домов значительно ниже, чем в большинстве других
#
# 8.  DIS - взвешенное расстояние до пяти центров занятости Бостона. Большинство районов расположены на относительно схожем расстоянии от рабочих центров,  так как медиана и среднее значение находятся рядом
#
#
#
# 9. TAX - ставка налога на недвижимость полной стоимости за $10,000. Медиана ниже среднего, высокое стандартное отклонение. Имеем выбросы с высокими значениями,  в некоторых районах налоговая ставка значительно выше, чем в  других.
#
# 10.  PTRATIO - соотношение учеников и учителей по городам. Среднее близко к медиане. В большинстве районов соотношение учеников и учителей похоже.
#
# 11. B - 1000(Bk - 0.63)^2, где Bk - доля чернокожего населения по городам.  Среднее близко к медиане, медина близка к максимуму высокое стандартное отклонение. В некоторых районах доля, проживающих  чернокожих ниже чем в других.
#
# 12. LSTAT - % населения с низким социальным статусом. Среднее значение близко к медиане, стандартное отклонение небольшое. Сильные выбросы отсутствуют
#
# 13. MEDV (TARGET)  - медианная стоимость домов, занимаемых владельцами, в тысячах долларов. Среднее значение близко к медиане, данные распределены относительно равномерно

# %% [markdown]
# 6. **Как влияет количество комнат (`RM`) на стоимость жилья (`MEDV`)?** [+0.5 балла]
#    - Построить диаграмму рассеяния между `RM` и `MEDV`.
#    - Рассчитать коэффициент корреляции Пирсона.
#    - Сделать письменный развернутый вывод в отдельной текстовой ячейке: влияет ли количество комнат и на стоимость жилья и почему? Логично ли это?

# %%
sns.scatterplot(data=df, x="RM", y="TARGET")
# Out:
# <Axes: xlabel='RM', ylabel='TARGET'>

# %%
corr_0 = df['RM'].corr(df['TARGET'])
print(f'коэффициент корреляции Пирсона {corr_0}')
# Out:
# коэффициент корреляции Пирсона 0.6953599470715393

# %% [markdown]
# Количество комнат  влияет на стоимость жилья, об этом говорит высокая положительня корреляция. Чем больше комнат в доме, тем выше его стоимость, так как это связано с большей площадью, большим комфортом и более высоким уровнем жилья. Высокая положительная корреляция подтверждает, что увеличение количества комнат приводит к увеличению стоимости жилья, что соответствует логике цены объекта недвижимости.

# %% [markdown]
# 7. **Существует ли связь между уровнем загрязнения (`NOX`) и расстоянием до центров занятости (`DIS`)?** [+0.5 балла]
#    - Визуализировать связь с помощью диаграммы рассеяния.
#    - Вычислить коэффициент корреляции.
#    - Сделать письменный развернутый вывод в отдельной текстовой ячейке: влияет ли уровень загрязнения на расстояние до центров занятости? Логично ли это?

# %%
sns.scatterplot(data=df, x="NOX", y="DIS")
# Out:
# <Axes: xlabel='NOX', ylabel='DIS'>

# %%
corr_1 = df['NOX'].corr(df['DIS'])
print(f'коэффициент корреляции Пирсона {corr_1}')
# Out:
# коэффициент корреляции Пирсона -0.7692301132258278

# %% [markdown]
# Высокая отрицательная корреляция между концентрацией оксидов азота и расстоянием до пяти центров занятости Бостона показывает, что что чем выше уровень загрязнения воздуха оксидами азота, тем ближе расположены центры занятости. Центры занятости чаще всего сосредоточены в густонаселённых городских районах, где выше уровень загрязнения воздуха  из-за интенсивного движения транспорта и больше промышленных предприятий .

# %% [markdown]
# 8. **Как влияет налоговая ставка (`TAX`) на соотношение учеников и учителей (`PTRATIO`)?** [+0.5 балла]
#    - Использовать корреляционный анализ для изучения связи. (Матрицу heatmap с Seaborn, матрицу корреляций)
#    - Сделать письменный развернутый вывод в отдельной текстовой ячейке: влияет ли налоговая ставка на соотношение учеников и учителей? Логично ли это?

# %%
sns.scatterplot(data=df, x="TAX", y="PTRATIO")
# Out:
# <Axes: xlabel='TAX', ylabel='PTRATIO'>

# %%
corr_2 = df['TAX'].corr(df['PTRATIO'])
print(corr_2)
# Out:
# 0.4608530350656667

# %%
corr_matrix = df[['TAX', 'PTRATIO']].corr()
sns.heatmap(corr_matrix, annot=True, cmap='cividis', fmt='.2f')
plt.title('Матрица корреляций между TAX и PTRATIO')
plt.show()

# %% [markdown]
# Есть явная, но не сильная положительная корреляция между ставкой налога на недвижимость и соотношением учеников и учителей. Это может быть связано с тем, что в районах с высокими налоговыми ставками больше ресурсов направляется на образование, что  привлекает больше  родителей и , соответственно, учеников, но не всегда приводит к увеличению числа учителей, так как выше уровень налогов. Возможно учителя здесь имеют более высокие зарплаты

# %% [markdown]
# 9. **Как социально-экономический статус (`LSTAT`) влияет на стоимость жилья (`MEDV`)?** [+0.5 балла]
#    - Анализировать взаимосвязь с помощью диаграммы рассеяния и корреляционного анализа (также матрица корреляции и heatmap от Seaborn)
#    - В чем разницы корелляции и причинно-следственной связи? Ответить на этот вопрос развернуто в отдельной текстовой ячейке

# %%
sns.scatterplot(data=df, x="LSTAT", y="TARGET")
# Out:
# <Axes: xlabel='LSTAT', ylabel='TARGET'>

# %%
corr_matrix_1 = df[['LSTAT', 'TARGET']].corr()
sns.heatmap(corr_matrix_1, annot=True, cmap='cividis', fmt='.2f')
plt.title('Матрица корреляций между TAX и PTRATIO')
plt.show()

# %% [markdown]
# У нас есть высокая отрицтельная корреляция между  долей населения с низким социально-экономическим статусом  и стоимостью жилья . С увеличением доли населения с низким социально-экономическим статусом стоимость жилья уменьшается. Это  связано с тем, что районы с высокой долей населения с низким социально-экономическим статусом  изначально имеют худшую инфраструктуру, более высокую преступность,  и дома в таких локациях стоят дешевле и привлекают менее платежеспособных покупателей. Если преступность высокая, увеличивается отток наиболее ууспешных жильцов района и так по кругу, район деградирует. Причина и следствие могут меняться местами. Поменять эту ситуацию можно вложениями в инфраструктуру и полным преобразованием района и повышением его престижности.
